# %% [markdown]
# ## **Install all packages**

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **Ignore warnings**

# %%
import warnings

# %%
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
# %matplotlib inline
import pandas as pd
import numpy as nm
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Seaborn functionality
#
# We got so many color palettes
#
# # Categorical color palettes

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)
plt.show()

# %% [markdown]
# # continous color palette

# %%
current_palette2 = sns.color_palette()

sns.palplot( sns.color_palette("Blues"))

plt.show()

# %% [markdown]
# ## **Diverging Color Palette**

# %%
current_palette3 = sns.color_palette()
sns.palplot(sns.color_palette("BrBG",20))
plt.show()

# %% [markdown]
# # **Seaborn on Titanic dataset**
#
#
# # sequential color_palette

# %%
current_palette3 = sns.color_palette()
sns.palplot(sns.color_palette("colorblind"))
plt.show()

# %%
full_data = pd.read_csv("titanic_dataset.csv")
full_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
full_data.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
full_data.shape
# Out:
# (891, 12)

# %%
full_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Distribution plots
#
#
# **Distplot()**

# %%
sns.histplot(full_data['Parch'], kde= False)
plt.show()

# %% [markdown]
# # Kdeplot
# ***Kernel Density Estimation (KDE)***
#
# ***Jointplot()***

# %%
sns.distplot(full_data['Age'], hist= False)
plt.show()
# Out:
# C:\Users\Alpha Tech\AppData\Local\Temp\ipykernel_17216\2026473979.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(full_data['Age'], hist= False)

# %%
plt.figure(figsize=(8,8))
sns.distplot(full_data["Age"])
plt.show()
# Out:
# C:\Users\Alpha Tech\AppData\Local\Temp\ipykernel_17216\2042802160.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(full_data["Age"])

# %% [markdown]
# # Relational Plot
#
# # relplot()

# %%
sns.relplot(x= "Age", y = "Fare",col = "Pclass",hue = "Sex",style = "Sex", kind = "line", data = full_data)
plt.show()
# Out:
# E:\ProgramData\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
full_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Scatterplot()

# %%
sns.scatterplot(x= "Age", y = "Fare",hue = "Sex", data = full_data)
plt.show()

# %% [markdown]
# # LinePlot()

# %%
sns.lineplot(x= "Age", y = "Fare",hue = "Sex",style = "Sex", data = full_data)
plt.show()

# %% [markdown]
# # categorical plot
# # barplot()

# %%
plt.figure(figsize = (8,8))
sns.barplot(x = "Sex" , y = "Survived", hue = "Pclass", data =full_data )
plt.show()

# %% [markdown]
# # stripplot()

# %%
plt.figure(figsize = (8,8))
sns.stripplot(x = "Sex" , y = "Age", hue = "Sex", data =full_data )
plt.show()

# %% [markdown]
# # swarmplot()

# %%
plt.figure(figsize = (8,8))
sns.swarmplot(x = "Sex" , y = "Age",hue = "Sex", data =full_data )
plt.show()

# %% [markdown]
# #boxplot()

# %%
plt.figure(figsize = (8,8))
sns.boxplot(x = "Survived" , y = "Age", hue = "Sex" , data =full_data )
plt.show()

# %% [markdown]
# # **Violinplot**()

# %%
plt.figure(figsize = (8,8))
sns.violinplot(x = "Survived" , y = "Age", hue = "Sex" , data =full_data )
plt.show()

# %% [markdown]
# #CountPlot()

# %%
plt.figure(figsize = (8,8))
sns.countplot(x = "Survived" ,  data =full_data , palette = "colorblind" )
plt.show()

# %% [markdown]
# # pointplot()

# %%
plt.figure(figsize = (8,8))
sns.pointplot(x = "Sex" , y = "Survived", hue = "Pclass" , data =full_data )
plt.show()

# %% [markdown]
# #Regression plots
#
# lmplot()

# %%
sns.lmplot(x = "Age", y = "Fare", data = full_data )
plt.show()
# Out:
# E:\ProgramData\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #regplot()

# %%
plt.subplots(figsize= (8,8))
sns.regplot(x = "Age", y = "Fare", data = full_data )
plt.show()

# %% [markdown]
# # stong correlation

# %%
plt.subplots(figsize= (10,10))
sns.regplot(x = "Fare", y = "Fare", data = full_data )
plt.show()

# %% [markdown]
# #heatmap

# %%
plt.subplots(figsize= (8,8))
sns.heatmap(full_data.corr() , cmap = "YlGnBu" , annot = True , fmt = ".2f" )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 2
#       1 plt.subplots(figsize= (8,8))
# ----> 2 sns.heatmap(full_data.corr() , cmap = "YlGnBu" , annot = True , fmt = ".2f" )
#       3 plt.show()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %% [markdown]
# # facetgrid.map

# %%
g = sns.FacetGrid(full_data , col = "Survived" , row = "Pclass")
g.map(plt.hist, "Age")
g.add_legend()
plt.show()

# %% [markdown]
# # training data pre-processing

# %%
df = pd.read_csv("/content/titanic_dataset.csv")
df.head(5)

# %%
print("train data :", df.shape)

# %%
df.describe()

# %%
df["Survived"].describe()

# %%
#data info
df.info()

# %% [markdown]
# # Missing data

# %%
sns.heatmap(df.isnull(),yticklabels = False , cbar = False, cmap = 'tab20c_r')
plt.title('missing data : training set')
plt.show()

# %%
plt.figure(figsize= (8,8))
sns.boxplot(x = 'Pclass', y = 'Age', data = df , palette  = 'GnBu_d').set_title('Age by passenger class')
plt.show()

# %% [markdown]
# #Imputation function

# %%
def impute_age(cols):
  Age = cols[0]
  Pclass = cols[1]

  if pd.isnull(Age):

    if Pclass == 1:
      return 37

    elif Pclass == 2:
      return 29

    else:
      return 24

  else:

    return Age
# apple the function to the age column
df["Age"] = df [["Age","Pclass"]].apply(impute_age,axis = 1)

# %% [markdown]
# The Cabin column has too many missing values to do anything useful with, so it would be best to remove it from the data frame altogether.

# %%
df.drop('Cabin', axis = 1 , inplace = True)

# %%
# remove rows with missing data
df.dropna(inplace = True)
df.head()

# %%
# remove unnecessary columns
df.drop(["Name","Ticket" ] , axis  = 1 , inplace = True )

# convert objects to the category data
objcat = ["Sex","Embarked" ]

for colname in objcat:
  df[colname] = df[colname].astype("category")

df.head()

# %% [markdown]
# # numeric features

# %%
df.describe()

# %%
#remove the passengerId
df.drop("PassengerId",axis = 1 , inplace = True)
df.head()

# %% [markdown]
# #Getting Model Ready

# %%
#shape the model
df.shape

# %%
#identify the categorical features
df.select_dtypes(["category"]).columns

# %%
#convert the categorcal features into dummy and indicator variables
sex = pd.get_dummies(df["Sex"], drop_first = True)
embarked   = pd.get_dummies(df["Embarked"], drop_first = True)

# %%
df.head()

# %%
#add new dummy columns to the data set
df = pd.concat ([df, sex, embarked], axis = 1)
df.head(5)

# %%
#drop the unnecessary columns
df.drop(["Sex", "Embarked"], axis = 1,inplace = True )

#shape the train data
print("train data :", df.shape)

#confirms the changes
df.head()

# %% [markdown]
# >Now the train data is perfect for a machine learning algorithm:
# - all the data is numeric
# - everything is concatenated together
#
#
#
# #**  Objective 2 - Machine learning**
# Next, I will feed these features into various classification algorithms to determine the best performance using a simple framework: **Split, Fit, Predict, Score It.**
#
#
# # Target variables

# %%
# split the data to be used in the models
# create matrix of features

x = df.drop("Survived", axis = 1) #graba everything else but "survived"

# create target variables
y = df['Survived'] # y is the column we are trying to predict

# %%
x # x respresents the features
x.shape

# %%
y # y represents the target
y.shape

# %%
# use x and y variables to split the taining data into train and test set

from sklearn.model_selection import train_test_split
x_train ,x_test, y_train , y_test = train_test_split(x , y ,test_size = .20 , random_state = 101)

# %%
x_train.shape
x_train

# %%
y_train.shape
y_train

# %%
x_test.shape
x_test

# %%
y_test.shape
y_test

# %%
#split data to be used on the models
#create matrix of features

x = df.drop("Survived", axis = 1 ) # grabs everything elsee but survived

#create target variable
y = df["Survived"] #y is the column we are trying to predict

# use x and y variables to split the training data into train and test set

from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y, test_size = .20, random_state = 101)

# %% [markdown]
# # model training

# %% [markdown]
# # logistic regression

# %%
#fit
# import model

from sklearn.linear_model import LogisticRegression

#create instance of model
Ireg = LogisticRegression()

# pass training data into model
Ireg.fit(x_train, y_train)

# %% [markdown]
# # model testing
#
# # class prediction

# %%
#predict
y_preg_Ireg = Ireg.predict(x_test)
print(y_preg_Ireg)
print(y_preg_Ireg.shape)

# %% [markdown]
# # probabilies of each class

# %%
probabilities = Ireg.predict_proba(x_test)[: , 1]
print(probabilities.shape)
print(probabilities)

# %% [markdown]
# # probabilities along with the class

# %%
for i in range(len(y_test)):
  print(round(probabilities[i], 3), "--->" , y_preg_Ireg[i])

# %% [markdown]
# # Model evaluation

# %%
# score it
from sklearn.metrics import classification_report , accuracy_score

print("Classification model")

#accuracy

print("--"*40)
logreg_accuracy = round(accuracy_score(y_test, y_preg_Ireg)*100, 2)
print("Accuracy ", logreg_accuracy, "%")

# %% [markdown]
# **classification model**
#
# # interpretation
#
# accuracy 81.12% of the model's predictions are correct.
